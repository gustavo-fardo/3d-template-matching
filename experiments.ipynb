# %%
import open3d as o3d
import numpy as np  
import matplotlib.pyplot as plt

pcd = o3d.io.read_point_cloud("Stella_1.pcd")
print(type(pcd))

labels = np.array(
    pcd.cluster_dbscan(eps=0.02, min_points=500, print_progress=True)
)

print("Cluster labels:", labels)
print("Number of clusters:", len(set(labels)) - (1 if -1 in labels else 0))

# --- Color each cluster ---
max_label = labels.max()
colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
colors[labels < 0] = [0, 0, 0, 1]  # noise points colored black

pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])  # keep RGB only

o3d.visualization.draw_geometries([pcd])
# Out:
# <class 'open3d.cpu.pybind.geometry.PointCloud'>
# Precompute neighbors.[========================================] 100%
# Cluster labels: [-1 -1 -1 ...  4  4  4]            ] 2%
# Number of clusters: 5

# %%
pcd = o3d.io.read_point_cloud("stella_template.pcd")
o3d.visualization.draw_geometries([pcd])

# %%
pcd = pcd.TetraMesh

# %%
o3d.visualization.draw_geometries([pcd])

# %%
import open3d as o3d
import numpy as np

pcdt = o3d.io.read_point_cloud("stella_template.pcd")

pcd = o3d.io.read_point_cloud("Stella_1.pcd")
pcd.estimate_normals()
mesh, densities = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd, depth=9)
bbox = pcd.get_axis_aligned_bounding_box()
mesh = mesh.crop(bbox)

N = len(pcdt.points)
resampled = mesh.sample_points_poisson_disk(number_of_points=N)

o3d.visualization.draw_geometries([resampled])
o3d.io.write_point_cloud("resampled.pcd", resampled)
# Out:
# True

# %%
from ultralytics import YOLO
import torchvision
print(torchvision.__version__)
model = YOLO("yolov8n.pt")
results = model.predict(source="Stella_right_1.png", save=True, show=True)
# Out:
# 0.15.1+cu117
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 import torchvision
#       3 print(torchvision.__version__)
# ----> 4 model = YOLO("yolov8n.pt")
#       5 results = model.predict(source="Stella_right_1.png", save=True, show=True)
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/ultralytics/models/yolo/model.py:81, in YOLO.__init__(self, model, task, verbose)
#      78     self.__dict__ = new_instance.__dict__
#      79 else:
#      80     # Continue with default YOLO initialization
# ---> 81     super().__init__(model=model, task=task, verbose=verbose)
#      82     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      83         from ultralytics import RTDETR
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/ultralytics/engine/model.py:149, in Model.__init__(self, model, task, verbose)
#     147     self._new(model, task=task, verbose=verbose)
#     148 else:
# --> 149     self._load(model, task=task)
#     151 # Delete super().training for accessing self.model.training
#     152 del self.training
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/ultralytics/engine/model.py:288, in Model._load(self, weights, task)
#     285 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     287 if str(weights).rpartition(".")[-1] == "pt":
# --> 288     self.model, self.ckpt = load_checkpoint(weights)
#     289     self.task = self.model.task
#     290     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/ultralytics/nn/tasks.py:1461, in load_checkpoint(weight, device, inplace, fuse)
#    1448 def load_checkpoint(weight, device=None, inplace=True, fuse=False):
#    1449     """Load a single model weights.
#    1450
#    1451     Args:
#    (...)
#    1459         ckpt (dict): Model checkpoint dictionary.
#    1460     """
# -> 1461     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1462     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1463     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/ultralytics/nn/tasks.py:1409, in torch_safe_load(weight, safe_only)
#    1407                 ckpt = torch_load(f, pickle_module=safe_pickle)
#    1408         else:
# -> 1409             ckpt = torch_load(file, map_location="cpu")
#    1411 except ModuleNotFoundError as e:  # e.name is missing module name
#    1412     if e.name == "models":
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/ultralytics/utils/patches.py:116, in torch_load(*args, **kwargs)
#     113 if TORCH_1_13 and "weights_only" not in kwargs:
#     114     kwargs["weights_only"] = False
# --> 116 return torch.load(*args, **kwargs)
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/torch/serialization.py:1097, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1095             except RuntimeError as e:
#    1096                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1097         return _load(
#    1098             opened_zipfile,
#    1099             map_location,
#    1100             pickle_module,
#    1101             overall_storage=overall_storage,
#    1102             **pickle_load_args,
#    1103         )
#    1104 if mmap:
#    1105     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/torch/serialization.py:1524, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1521 unpickler.persistent_load = persistent_load
#    1522 # Needed for tensors where storage device and rebuild tensor device are
#    1523 # not connected (wrapper subclasses and tensors rebuilt using numpy)
# -> 1524 torch._utils._thread_local_state.map_location = map_location
#    1525 result = unpickler.load()
#    1526 del torch._utils._thread_local_state.map_location
#
# File ~/3d-template-matching/venv/lib/python3.8/site-packages/torch/__init__.py:2216, in __getattr__(name)
#    2213     import importlib
#    2214     return importlib.import_module(f".{name}", __name__)
# -> 2216 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute '_utils'
